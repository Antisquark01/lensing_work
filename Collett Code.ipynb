# %%
import numpy as np
import matplotlib.pyplot as plt
import _pickle as cPickle
import sys, chardet

# %%
# f1 = open("/Users/ethansilver/Downloads/LensPop/idealisedlenses/lenspopulation_lsst_residual_119760.pkl",'rb')
f2 = open("/Users/ethansilver/Downloads/LensPop/idealisedlenses/lenspopulation_lsst_0.pkl",'rb')
# lenses1 = cPickle.load(f1, encoding="latin1")
lenses2 = cPickle.load(f2, encoding="latin1")
# lenses[120000]['b']

# %%
# thetaEs1 = []
# for key in lenses1.keys():
#     thetaEs1.append(lenses1[key]['b'][1])
# thetaEs1 = np.array(thetaEs1)

thetaEs2 = []
for key in lenses2.keys():
    thetaEs2.append(lenses2[key]['b'][1])
thetaEs2 = np.array(thetaEs2)


sig = []
for key in lenses2.keys():
    sig.append(lenses2[key]['sigl'])
sig = np.array(sig)

# %%
plt.hist(sig)
# Out:
# (array([ 459., 1043., 1765., 2193., 2027., 1355.,  710.,  344.,   81.,
#           23.]),
#  array([ 99.32895661, 128.68964216, 158.05032772, 187.41101328,
#         216.77169884, 246.13238439, 275.49306995, 304.85375551,
#         334.21444107, 363.57512662, 392.93581218]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(thetaEs2)
sum(thetaEs2>1)
# Out:
# 2063

# %%
577*100
# Out:
# 57700

# %%
lenses2
# Out:
# {0: {'zl': 1.4870468777037515,
#   'lens?': True,
#   'sigl': 201.76398515399597,
#   'mhalo': {1: 0.0677},
#   'xs': {1: -0.0207588714405555},
#   'ys': {1: 0.20694968201933886},
#   'zs': {1: 6.0359},
#   'ps': {1: 4.886531708034796},
#   'qs': {1: 0.3088466561294839},
#   'b': {1: 0.5573359729235952},
#   'rs': {1: 0.23310127666812583},
#   'ml': {'r_SDSS': 27.92194013256392,
#    'z_SDSS': 24.457831722854948,
#    'F814W_ACS': 25.092145158258997,
#    'Y_UKIRT': 23.358118561558406,
#    'g_SDSS': 29.085795090787137,
#    'i_SDSS': 25.71687241993557},
#   'ms': {1: {'r_SDSS': 27.5644,
#     'z_SDSS': 27.912,
#     'F814W_ACS': 28.7056,
#     'Y_UKIRT': 2763.288,
#     'g_SDSS': 27.3875,
#     'i_SDSS': 28.7056}},
#   'rl': {'r_SDSS': 0.3476758599505128,
#    'z_SDSS': 0.3476758599505128,
#    'F814W_ACS': 0.3476758599505128,
#    'Y_UKIRT': 0.3476758599505128,
#    'g_SDSS': 0.3476758599505128,
#    'i_SDSS': 0.3476758599505128},
#   'mstar': {1: 7.2295},
# ...
